# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishwas-Shabadi/Assignment/blob/master/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (1) Create the below pattern using nested for loop in Python.
# * x
# * xx
# * xxx
# * xxxx
# * xxxxx
# * xxxx
# * xxx
# * xx
# * x

# %%
shape = [1, 2, 3, 4, 5, 4, 3, 2, 1]
for number in shape:
  output = ''
  for count in range(number):
    output += '*'
  print(output)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# (2) Write a Python program to reverse a word after accepting the input from the user.

# %%
word = input("Enter a word - ")
word_reverse = reversed(list(word))
sep = ''
print(sep.join(word_reverse))
# Out:
# Enter a word - ineuron
# norueni
